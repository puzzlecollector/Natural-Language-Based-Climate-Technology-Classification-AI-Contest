# %%
import torch 
import torch.nn as nn 
import torch.functional as f
from torch.utils.data import TensorDataset, DataLoader, RandomSampler, SequentialSampler
from sklearn.model_selection import train_test_split
import time
import datetime
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import random 
import re 
import math 
from tqdm import tqdm 
import sklearn
from transformers import *
from kobert_tokenizer import KoBERTTokenizer
# Out:
# PyTorch version 1.7.0+cu110 available.
# TensorFlow version 2.5.0 available.

# %%
train = pd.read_csv("open/train.csv") 
test = pd.read_csv("open/test.csv") 

train.shape, test.shape, train['label'].nunique()
# Out:
# ((174304, 13), (43576, 12), 46)

# %%
submission = pd.read_csv("open/sample_submission.csv")

# %%
def clean_text(sent):
    sent_clean=re.sub("[^가-힣ㄱ-하-ㅣ]", " ", sent)
    return sent_clean

# %%
def split_text(s, overlap = 20, chunk_size = 50): 
    total = [] 
    partial = [] 
    if len(s.split()) // (chunk_size - overlap) > 0:  
        n = len(s.split()) // (chunk_size - overlap) 
    else: 
        n = 1 
    for w in range(n): 
        if w == 0: 
            partial = s.split()[:chunk_size] 
            total.append(" ".join(partial)) 
        else:  
            partial = s.split()[w*(chunk_size - overlap):w*(chunk_size - overlap) + chunk_size]
            total.append(" ".join(partial)) 
    return total

# %%
train['요약문_내용'] = train['요약문_연구목표'] + train['요약문_연구내용'] + train['요약문_기대효과'] 
test['요약문_내용'] = test['요약문_연구목표'] + test['요약문_연구내용'] + test['요약문_기대효과']

# %%
train['요약문_내용'].fillna('NAN',inplace=True) 
test['요약문_내용'].fillna('NAN',inplace=True)

# %%
train['사업명'].fillna('NAN',inplace=True) 
train['사업_부처명'].fillna('NAN',inplace=True) 
train['내역사업명'].fillna('NAN',inplace=True) 
train['과제명'].fillna('NAN',inplace=True) 
train['요약문_한글키워드'].fillna('NAN',inplace=True)

# %%
contents = train['요약문_내용'].values 
feature1 = train['사업명'].values 
feature2 = train['사업_부처명'].values 
feature3 = train['내역사업명'].values 
feature4 = train['과제명'].values 
feature5 = train['요약문_한글키워드'].values 
feature6 = train['label'].values 

train_data = {'사업명':[],'사업_부처명':[],'내역사업명':[],'과제명':[],'한글키워드':[],'요약문':[],'label':[]} 

for i in tqdm(range(contents.shape[0]), position = 0, leave = True): 
    sample = str(contents[i]) 
    splitted_text = split_text(clean_text(sample)) 
    for t in splitted_text: 
        train_data['요약문'].append(t) 
        train_data['사업명'].append(clean_text(str(feature1[i])))
        train_data['사업_부처명'].append(clean_text(str(feature2[i]))) 
        train_data['내역사업명'].append(clean_text(str(feature3[i]))) 
        train_data['과제명'].append(clean_text(str(feature4[i])))  
        train_data['한글키워드'].append(feature5[i]) # no cleaning for this one
        train_data['label'].append(feature6[i])
# Out:
# 100%|██████████| 174304/174304 [03:07<00:00, 929.93it/s]

# %%
train_data = pd.DataFrame(train_data)

# %%
## Now we tokenize each data and make sure they all lie within the 512 tokenization range 
## if not check how many have token length greater than 512 

tokenizer = KoBERTTokenizer.from_pretrained('skt/kobert-base-v1')


def bert_tokenizer(sent, MAX_LEN):  
    encoded_dict = tokenizer.encode_plus(
        text = sent, 
        add_special_tokens = True, # add [CLS] and [SEP]
        pad_to_max_length = False, 
        return_attention_mask = True # constructing attention_masks 
    )  
    
    input_id = encoded_dict['input_ids'] 
    attention_mask = encoded_dict['attention_mask'] # differentiate padding from non padding 
    token_type_id = encoded_dict['token_type_ids'] # differentiate two sentences, not "really" necessary for now    
    
    if len(input_id) > 512: # head + tail methodology 
        input_id = input_id[:512]  
        attention_mask = attention_mask[:512]  
        token_type_id = token_type_id[:512]     
        print("Long Text!! Using the first 512 tokens")
    elif len(input_id) <= 512: 
        input_id = input_id + [0]*(512 - len(input_id)) 
        attention_mask = attention_mask + [0]*(512 - len(attention_mask))
        token_type_id = token_type_id + [0]*(512 - len(token_type_id))  
        
    return input_id, attention_mask, token_type_id

# %%
train_data['data'] = train_data['사업명'] + " " + train_data['사업_부처명'] + " " + train_data['내역사업명'] + " " + train_data['과제명'] + " " + train_data['한글키워드'] + " " + train_data['요약문'] 

train_data.head(2)
# Out:
#         사업명 사업_부처명     내역사업명                           과제명  \
# 0  농업기초기반연구  농촌진흥청  농산물안전성연구  유전정보를 활용한 새로운 해충 분류군 동정기술 개발
# 1  농업기초기반연구  농촌진흥청  농산물안전성연구  유전정보를 활용한 새로운 해충 분류군 동정기술 개발
#
#                               한글키워드  \
# 0  뉴클레오티드 염기서열, 분자마커, 종 동정, 침샘, 전사체
# 1  뉴클레오티드 염기서열, 분자마커, 종 동정, 침샘, 전사체
#
#                                                  요약문  label  \
# 0  새로운 해충분류군의 동정기술 개발 및 유입확산 추적 가 외래 및 돌발해충의 발생조사...     24
# 1  의 돌발 및 외래해충 다 외래 및 돌발해충의 유전적 다양성 조사 시험곤충 나 의 해...     24
#
#                                                 data
# 0  농업기초기반연구 농촌진흥청 농산물안전성연구 유전정보를 활용한 새로운 해충 분류군 동...
# 1  농업기초기반연구 농촌진흥청 농산물안전성연구 유전정보를 활용한 새로운 해충 분류군 동...

# %%
train_text = train_data['data'].values 
train_labels = train_data['label'].values

# %%
BATCH_SIZE = 32
NUM_EPOCHS = 30
VALID_SPLIT = 0.1 
MAX_LEN = 512 # max token size for BERT, ELECTRA

# %%
N = train_data.shape[0] 

input_ids = np.zeros((N, MAX_LEN),dtype=int)
attention_masks = np.zeros((N, MAX_LEN),dtype=int)
token_type_ids = np.zeros((N, MAX_LEN),dtype=int) 
labels = np.zeros((N),dtype=int)

for i in tqdm(range(N), position=0, leave=True): 
    try:
        cur_str = train_text[i]
        cur_label = train_labels[i]
        input_id, attention_mask, token_type_id = bert_tokenizer(cur_str, MAX_LEN=MAX_LEN) 
        input_ids[i,] = input_id 
        attention_masks[i,] = attention_mask 
        token_type_ids[i,] = token_type_id
        labels[i] = cur_label 
    except Exception as e: 
        print(e)
        print(cur_str)
        pass
# Out:
#   5%|▍         | 79939/1638867 [02:14<44:54, 578.58it/s]
# Long Text!! Using the first 512 tokens
#   8%|▊         | 122944/1638867 [03:25<39:41, 636.45it/s]
# Long Text!! Using the first 512 tokens
#   8%|▊         | 138415/1638867 [03:50<44:06, 566.94it/s]
# Long Text!! Using the first 512 tokens
#  11%|█         | 173087/1638867 [04:52<43:14, 565.02it/s]
# Long Text!! Using the first 512 tokens
# Long Text!! Using the first 512 tokens
# Long Text!! Using the first 512 tokens
#  11%|█         | 178421/1638867 [05:01<43:33, 558.73it/s]
# Long Text!! Using the first 512 tokens
#  14%|█▍        | 233820/1638867 [06:35<41:29, 564.34it/s]
# Long Text!! Using the first 512 tokens
# Long Text!! Using the first 512 tokens
# Long Text!! Using the first 512 tokens
#  15%|█▌        | 251064/1638867 [07:05<46:31, 497.14it/s]
# Long Text!! Using the first 512 tokens
#  16%|█▌        | 258665/1638867 [07:18<39:36, 580.83it/s]
# Long Text!! Using the first 512 tokens
#  29%|██▉       | 475568/1638867 [13:22<31:28, 615.87it/s]
# Long Text!! Using the first 512 tokens
#  30%|██▉       | 489033/1638867 [13:45<34:00, 563.38it/s]
# Long Text!! Using the first 512 tokens
#  33%|███▎      | 545079/1638867 [15:22<29:11, 624.54it/s]
# Long Text!! Using the first 512 tokens
#  35%|███▍      | 569102/1638867 [16:01<30:13, 589.74it/s]
# Long Text!! Using the first 512 tokens
#  35%|███▌      | 576093/1638867 [16:13<28:20, 624.84it/s]
# Long Text!! Using the first 512 tokens
#  36%|███▌      | 582067/1638867 [16:24<28:29, 618.11it/s]
# Long Text!! Using the first 512 tokens
# Long Text!! Using the first 512 tokens
# Long Text!! Using the first 512 tokens
#  38%|███▊      | 624191/1638867 [17:33<29:42, 569.24it/s]
# Long Text!! Using the first 512 tokens
#  40%|████      | 657183/1638867 [18:30<29:09, 561.09it/s]
# Long Text!! Using the first 512 tokens
#  44%|████▎     | 713166/1638867 [20:06<26:40, 578.34it/s]
# Long Text!! Using the first 512 tokens
#  45%|████▍     | 733685/1638867 [20:41<27:58, 539.26it/s]
# Long Text!! Using the first 512 tokens
#  45%|████▌     | 743931/1638867 [20:59<28:21, 526.06it/s]
# Long Text!! Using the first 512 tokens
#  46%|████▌     | 748278/1638867 [21:06<25:39, 578.48it/s]
# Long Text!! Using the first 512 tokens
#  49%|████▊     | 796773/1638867 [22:30<23:35, 594.89it/s]
# Long Text!! Using the first 512 tokens
#  49%|████▉     | 805568/1638867 [22:45<23:11, 599.05it/s]
# Long Text!! Using the first 512 tokens
#  52%|█████▏    | 854252/1638867 [24:07<21:52, 597.86it/s]
# Long Text!! Using the first 512 tokens
# Long Text!! Using the first 512 tokens
#  55%|█████▍    | 895825/1638867 [25:19<23:04, 536.87it/s]
# Long Text!! Using the first 512 tokens
# Long Text!! Using the first 512 tokens
#  58%|█████▊    | 947976/1638867 [26:51<20:12, 569.67it/s]
# Long Text!! Using the first 512 tokens
#  65%|██████▌   | 1068793/1638867 [30:15<13:56, 681.69it/s]
# Long Text!! Using the first 512 tokens
#  66%|██████▋   | 1087490/1638867 [30:46<15:33, 590.88it/s]
# Long Text!! Using the first 512 tokens
# Long Text!! Using the first 512 tokens
# Long Text!! Using the first 512 tokens
#  72%|███████▏  | 1185207/1638867 [33:32<11:39, 648.85it/s]
# Long Text!! Using the first 512 tokens
# Long Text!! Using the first 512 tokens
#  72%|███████▏  | 1186957/1638867 [33:35<13:16, 567.12it/s]
# Long Text!! Using the first 512 tokens
#  73%|███████▎  | 1199358/1638867 [33:56<13:11, 555.43it/s]
# Long Text!! Using the first 512 tokens
#  75%|███████▍  | 1222390/1638867 [34:36<13:06, 529.52it/s]
# Long Text!! Using the first 512 tokens
#  75%|███████▍  | 1225518/1638867 [34:41<11:45, 585.58it/s]
# Long Text!! Using the first 512 tokens
#  75%|███████▌  | 1233813/1638867 [34:55<12:49, 526.55it/s]
# Long Text!! Using the first 512 tokens
#  83%|████████▎ | 1353133/1638867 [38:19<07:57, 597.79it/s]
# Long Text!! Using the first 512 tokens
# Long Text!! Using the first 512 tokens
#  84%|████████▍ | 1373809/1638867 [38:54<07:47, 567.37it/s]
# Long Text!! Using the first 512 tokens
#  86%|████████▌ | 1410435/1638867 [39:58<06:13, 611.22it/s]
# Long Text!! Using the first 512 tokens
#  87%|████████▋ | 1422052/1638867 [40:17<06:08, 588.26it/s]
# Long Text!! Using the first 512 tokens
#  89%|████████▉ | 1454967/1638867 [41:13<05:10, 593.05it/s]
# Long Text!! Using the first 512 tokens
# Long Text!! Using the first 512 tokens
#  95%|█████████▍| 1554722/1638867 [44:07<02:34, 543.97it/s]
# Long Text!! Using the first 512 tokens
# 100%|██████████| 1638867/1638867 [46:32<00:00, 586.81it/s]

# %%
input_ids = torch.tensor(input_ids, dtype=int)
attention_masks = torch.tensor(attention_masks, dtype=int)
token_type_ids = torch.tensor(token_type_ids, dtype=int) 
labels = torch.tensor(labels, dtype=int)

# %%
train_inputs, val_inputs, train_labels, val_labels = train_test_split(input_ids, labels, random_state = 5678, test_size = VALID_SPLIT, stratify=labels) 

train_attention_mask, val_attention_mask, _, _ = train_test_split(attention_masks, labels, random_state = 5678, test_size = VALID_SPLIT, stratify=labels) 

train_token_ids, val_token_ids, _, _ = train_test_split(token_type_ids, labels, random_state = 5678, test_size = VALID_SPLIT, stratify=labels) 


train_inputs.shape, train_attention_mask.shape, train_token_ids.shape, train_labels.shape, val_inputs.shape, val_attention_mask.shape, val_token_ids.shape, val_labels.shape
# Out:
# (torch.Size([1474980, 512]),
#  torch.Size([1474980, 512]),
#  torch.Size([1474980, 512]),
#  torch.Size([1474980]),
#  torch.Size([163887, 512]),
#  torch.Size([163887, 512]),
#  torch.Size([163887, 512]),
#  torch.Size([163887]))

# %%
batch_size = 32 
train_data = TensorDataset(train_inputs, train_attention_mask, train_token_ids, train_labels) 
train_sampler = RandomSampler(train_data) 
train_dataloader = DataLoader(train_data, sampler=train_sampler, batch_size=batch_size) 

validation_data = TensorDataset(val_inputs, val_attention_mask, val_token_ids, val_labels) 
validation_sampler = SequentialSampler(validation_data) 
validation_dataloader = DataLoader(validation_data, sampler=validation_sampler, batch_size=batch_size)

# %%
model = BertForSequenceClassification.from_pretrained("skt/kobert-base-v1", num_labels=46)
model.cuda()
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=535.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=368792544.0, style=ProgressStyle(descri…
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at skt/kobert-base-v1 and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# BertForSequenceClassification(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(8002, 768, padding_idx=1)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (1): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (2): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (3): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (4): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (5): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (6): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (7): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (8): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (9): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (10): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (11): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (dropout): Dropout(p=0.1, inplace=False)
#   (classifier): Linear(in_features=768, out_features=46, bias=True)
# )

# %%
optimizer = AdamW(model.parameters(), lr=2e-5, eps=1e-8)

epochs = 10

total_steps = len(train_dataloader) * epochs 

scheduler = get_linear_schedule_with_warmup(optimizer, 
                                            num_warmup_steps = 0,
                                            num_training_steps = total_steps)


def flat_accuracy(preds, labels): 
    pred_flat = np.argmax(preds, axis=1).flatten() 
    labels_flat = labels.flatten() 
    return np.sum(pred_flat == labels_flat) / len(labels_flat) 

def format_time(elapsed):
    # 반올림
    elapsed_rounded = int(round((elapsed)))
    # hh:mm:ss으로 형태 변경
    return str(datetime.timedelta(seconds=elapsed_rounded))


device = torch.device("cuda")


# 그래디언트 초기화
model.zero_grad()

# 에폭만큼 반복
for epoch_i in range(0, epochs):
    
    # ========================================
    #               Training
    # ========================================
    
    print("")
    print('======== Epoch {:} / {:} ========'.format(epoch_i + 1, epochs))
    print('Training...')

    # 시작 시간 설정
    t0 = time.time()

    # 로스 초기화
    total_loss = 0

    # 훈련모드로 변경
    model.train()
        
    # 데이터로더에서 배치만큼 반복하여 가져옴
    for step, batch in enumerate(train_dataloader):
        # 경과 정보 표시
        if step % 500 == 0 and not step == 0:
            elapsed = format_time(time.time() - t0)
            print('  Batch {:>5,}  of  {:>5,}.    Elapsed: {:}.'.format(step, len(train_dataloader), elapsed))
            print('  current average loss = {}'.format(total_loss / step))

        # 배치를 GPU에 넣음
        batch = tuple(t.to(device) for t in batch)
        
        # 배치에서 데이터 추출
        b_input_ids, b_input_mask, b_token_type_ids, b_labels = batch

        # Forward 수행                
        outputs = model(b_input_ids, 
                        token_type_ids=b_token_type_ids, 
                        attention_mask=b_input_mask, 
                        labels=b_labels)
        
        # 로스 구함
        loss = outputs[0]

        # 총 로스 계산
        total_loss += loss.item()

        # Backward 수행으로 그래디언트 계산
        loss.backward()

        # 그래디언트 클리핑
        torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)

        # 그래디언트를 통해 가중치 파라미터 업데이트
        optimizer.step()

        # 스케줄러로 학습률 감소
        scheduler.step()

        # 그래디언트 초기화
        model.zero_grad()

    # 평균 로스 계산
    avg_train_loss = total_loss / len(train_dataloader)            

    print("")
    print("  Average training loss: {}".format(avg_train_loss))
    print("  Training epoch took: {:}".format(format_time(time.time() - t0)))
        
    # ========================================
    #               Validation
    # ========================================

    print("")
    print("Running Validation...")

    #시작 시간 설정
    t0 = time.time()

    # 평가모드로 변경
    model.eval()

    # 변수 초기화
    eval_loss, eval_accuracy = 0, 0
    nb_eval_steps, nb_eval_examples = 0, 0

    # 데이터로더에서 배치만큼 반복하여 가져옴
    for batch in validation_dataloader:
        # 배치를 GPU에 넣음
        batch = tuple(t.to(device) for t in batch)
        
        # 배치에서 데이터 추출
        b_input_ids, b_input_mask, b_token_type_ids, b_labels = batch
        
        # 그래디언트 계산 안함
        with torch.no_grad():     
            # Forward 수행
            outputs = model(b_input_ids, 
                            token_type_ids=b_token_type_ids, 
                            attention_mask=b_input_mask, 
                            labels = b_labels)
    
        
        loss = outputs[0] 
        logits = outputs[1] 
        
        # 로스 구함 
        eval_loss += loss.item() 
        
        # CPU로 데이터 이동
        logits = logits.detach().cpu().numpy()
        label_ids = b_labels.to('cpu').numpy()
        
        # 출력 로짓과 라벨을 비교하여 정확도 계산
        tmp_eval_accuracy = flat_accuracy(logits, label_ids)
        eval_accuracy += tmp_eval_accuracy
        nb_eval_steps += 1
    
    avg_val_loss = eval_loss / len(validation_dataloader)            
    print("  Average validation loss: {}".format(avg_val_loss))
    print("  Accuracy: {}".format(eval_accuracy/nb_eval_steps))
    print("  Validation took: {:}".format(format_time(time.time() - t0)))
    
    torch.save(model.state_dict(), "KoBERT_DIFFERENT_CONFIG_" + str(epoch_i + 1)) 
    

print("")
print("Training complete!")
# Out:
# ======== Epoch 1 / 10 ========
# Training...
#   Batch   500  of  46,094.    Elapsed: 0:08:22.
#   current average loss = 1.0394093351811171
#   Batch 1,000  of  46,094.    Elapsed: 0:16:43.
#   current average loss = 0.8381642836257815
#   Batch 1,500  of  46,094.    Elapsed: 0:25:04.
#   current average loss = 0.7416638403125108
#   Batch 2,000  of  46,094.    Elapsed: 0:33:26.
#   current average loss = 0.6740569929247722
#   Batch 2,500  of  46,094.    Elapsed: 0:41:48.
#   current average loss = 0.6300022935830056
#   Batch 3,000  of  46,094.    Elapsed: 0:50:09.
#   current average loss = 0.5910384592091044
#   Batch 3,500  of  46,094.    Elapsed: 0:58:30.
#   current average loss = 0.5605949303901622
#   Batch 4,000  of  46,094.    Elapsed: 1:06:52.
#   current average loss = 0.5360350472899154
#   Batch 4,500  of  46,094.    Elapsed: 1:15:15.
#   current average loss = 0.5153200819359885
#   Batch 5,000  of  46,094.    Elapsed: 1:23:35.
#   current average loss = 0.49687080581914633
#   Batch 5,500  of  46,094.    Elapsed: 1:31:56.
#   current average loss = 0.4817534601927142
#   Batch 6,000  of  46,094.    Elapsed: 1:40:17.
#   current average loss = 0.4683352029793896
#   Batch 6,500  of  46,094.    Elapsed: 1:48:38.
#   current average loss = 0.45516332912545365
#   Batch 7,000  of  46,094.    Elapsed: 1:57:00.
#   current average loss = 0.44308048596366173
#   Batch 7,500  of  46,094.    Elapsed: 2:05:22.
#   current average loss = 0.43214670820981266
#   Batch 8,000  of  46,094.    Elapsed: 2:13:46.
#   current average loss = 0.42188292228477076
#   Batch 8,500  of  46,094.    Elapsed: 2:22:09.
#   current average loss = 0.41196610377948073
#   Batch 9,000  of  46,094.    Elapsed: 2:30:30.
#   current average loss = 0.40357297451856233
#   Batch 9,500  of  46,094.    Elapsed: 2:38:53.
#   current average loss = 0.3950386732438285
#   Batch 10,000  of  46,094.    Elapsed: 2:47:15.
#   current average loss = 0.38710167474998164
#   Batch 10,500  of  46,094.    Elapsed: 2:55:36.
#   current average loss = 0.37939845090527974
#   Batch 11,000  of  46,094.    Elapsed: 3:03:58.
#   current average loss = 0.37267996967287564
#   Batch 11,500  of  46,094.    Elapsed: 3:12:19.
#   current average loss = 0.3662800677753985
#   Batch 12,000  of  46,094.    Elapsed: 3:20:42.
#   current average loss = 0.3602390637329469
#   Batch 12,500  of  46,094.    Elapsed: 3:29:05.
#   current average loss = 0.3542675830937922
#   Batch 13,000  of  46,094.    Elapsed: 3:37:27.
#   current average loss = 0.34880761556141077
#   Batch 13,500  of  46,094.    Elapsed: 3:45:49.
#   current average loss = 0.3433520483037595
#   Batch 14,000  of  46,094.    Elapsed: 3:54:10.
#   current average loss = 0.3384246831690294
#   Batch 14,500  of  46,094.    Elapsed: 4:02:32.
#   current average loss = 0.33321781002187395
#   Batch 15,000  of  46,094.    Elapsed: 4:10:53.
#   current average loss = 0.32815851471762486
#   Batch 15,500  of  46,094.    Elapsed: 4:19:15.
#   current average loss = 0.3238400679501074
#   Batch 16,000  of  46,094.    Elapsed: 4:27:36.
#   current average loss = 0.31930198097860557
#   Batch 16,500  of  46,094.    Elapsed: 4:35:56.
#   current average loss = 0.31520828989427535
#   Batch 17,000  of  46,094.    Elapsed: 4:44:17.
#   current average loss = 0.31114440332136717
#   Batch 17,500  of  46,094.    Elapsed: 4:52:38.
#   current average loss = 0.3070491313832413
#   Batch 18,000  of  46,094.    Elapsed: 5:00:59.
#   current average loss = 0.30321269614865176
#   Batch 18,500  of  46,094.    Elapsed: 5:09:22.
#   current average loss = 0.29960077102385413
#   Batch 19,000  of  46,094.    Elapsed: 5:17:43.
#   current average loss = 0.2961110550896877
#   Batch 19,500  of  46,094.    Elapsed: 5:26:05.
#   current average loss = 0.29261143834628645
#   Batch 20,000  of  46,094.    Elapsed: 5:34:26.
#   current average loss = 0.28917981571597046
#   Batch 20,500  of  46,094.    Elapsed: 5:42:47.
#   current average loss = 0.28581384149602634
#   Batch 21,000  of  46,094.    Elapsed: 5:51:08.
#   current average loss = 0.28264085920682797
#   Batch 21,500  of  46,094.    Elapsed: 5:59:31.
#   current average loss = 0.2793832019901683
#   Batch 22,000  of  46,094.    Elapsed: 6:07:51.
#   current average loss = 0.2762045074216175
#   Batch 22,500  of  46,094.    Elapsed: 6:16:12.
#   current average loss = 0.2731496942477818
#   Batch 23,000  of  46,094.    Elapsed: 6:24:32.
#   current average loss = 0.2703625111941694
#   Batch 23,500  of  46,094.    Elapsed: 6:32:53.
#   current average loss = 0.2675030502472271
#   Batch 24,000  of  46,094.    Elapsed: 6:41:14.
#   current average loss = 0.26482141400555703
#   Batch 24,500  of  46,094.    Elapsed: 6:49:35.
#   current average loss = 0.2621868337994389
#   Batch 25,000  of  46,094.    Elapsed: 6:57:55.
#   current average loss = 0.2594877061844873
#   Batch 25,500  of  46,094.    Elapsed: 7:06:19.
#   current average loss = 0.2568307976296569
#   Batch 26,000  of  46,094.    Elapsed: 7:14:40.
#   current average loss = 0.2543626963809791
#   Batch 26,500  of  46,094.    Elapsed: 7:23:01.
#   current average loss = 0.2519181377146336
#   Batch 27,000  of  46,094.    Elapsed: 7:31:21.
#   current average loss = 0.2495532504045814
#   Batch 27,500  of  46,094.    Elapsed: 7:39:42.
#   current average loss = 0.24742788028156765
#   Batch 28,000  of  46,094.    Elapsed: 7:48:02.
#   current average loss = 0.24516213478868304
#   Batch 28,500  of  46,094.    Elapsed: 7:56:24.
#   current average loss = 0.24299449864091768
#   Batch 29,000  of  46,094.    Elapsed: 8:04:45.
#   current average loss = 0.24072620769936376
#   Batch 29,500  of  46,094.    Elapsed: 8:13:06.
#   current average loss = 0.23855375541909005
#   Batch 30,000  of  46,094.    Elapsed: 8:21:26.
#   current average loss = 0.23654588125198497
#   Batch 30,500  of  46,094.    Elapsed: 8:29:46.
#   current average loss = 0.23467437285151463
#   Batch 31,000  of  46,094.    Elapsed: 8:38:07.
#   current average loss = 0.23261371359407465
#   Batch 31,500  of  46,094.    Elapsed: 8:46:28.
#   current average loss = 0.23048253717582437
#   Batch 32,000  of  46,094.    Elapsed: 8:54:50.
#   current average loss = 0.22845764385084658
#   Batch 32,500  of  46,094.    Elapsed: 9:03:09.
#   current average loss = 0.22657216190949547
#   Batch 33,000  of  46,094.    Elapsed: 9:11:30.
#   current average loss = 0.22464710667005663
#   Batch 33,500  of  46,094.    Elapsed: 9:19:50.
#   current average loss = 0.22267877631346564
#   Batch 34,000  of  46,094.    Elapsed: 9:28:10.
#   current average loss = 0.22103681649876972
#   Batch 34,500  of  46,094.    Elapsed: 9:36:31.
#   current average loss = 0.21915343415034105
#   Batch 35,000  of  46,094.    Elapsed: 9:44:51.
#   current average loss = 0.21744826196290754
#   Batch 35,500  of  46,094.    Elapsed: 9:53:11.
#   current average loss = 0.21583139063709442
#   Batch 36,000  of  46,094.    Elapsed: 10:01:33.
#   current average loss = 0.21420396966698982
#   Batch 36,500  of  46,094.    Elapsed: 10:09:53.
#   current average loss = 0.21258570585160977
#   Batch 37,000  of  46,094.    Elapsed: 10:18:12.
#   current average loss = 0.21102039589027
#   Batch 37,500  of  46,094.    Elapsed: 10:26:33.
#   current average loss = 0.20935880206438326
#   Batch 38,000  of  46,094.    Elapsed: 10:34:54.
#   current average loss = 0.20790148161603736
#   Batch 38,500  of  46,094.    Elapsed: 10:43:15.
#   current average loss = 0.2063317634235537
#   Batch 39,000  of  46,094.    Elapsed: 10:51:35.
#   current average loss = 0.20490234152866207
#   Batch 39,500  of  46,094.    Elapsed: 10:59:55.
#   current average loss = 0.20343344740690353
#   Batch 40,000  of  46,094.    Elapsed: 11:08:17.
#   current average loss = 0.2019105572891902
#   Batch 40,500  of  46,094.    Elapsed: 11:16:36.
#   current average loss = 0.20063485427672564
#   Batch 41,000  of  46,094.    Elapsed: 11:24:57.
#   current average loss = 0.19920480042561908
#   Batch 41,500  of  46,094.    Elapsed: 11:33:17.
#   current average loss = 0.19777151616069935
#   Batch 42,000  of  46,094.    Elapsed: 11:41:37.
#   current average loss = 0.19644230606098634
#   Batch 42,500  of  46,094.    Elapsed: 11:49:58.
#   current average loss = 0.1950930613385712
#   Batch 43,000  of  46,094.    Elapsed: 11:58:17.
#   current average loss = 0.19379301383256367
#   Batch 43,500  of  46,094.    Elapsed: 12:06:38.
#   current average loss = 0.19248861184787747
#   Batch 44,000  of  46,094.    Elapsed: 12:14:58.
#   current average loss = 0.19122593577818572
#   Batch 44,500  of  46,094.    Elapsed: 12:23:18.
#   current average loss = 0.1899930844064573
#   Batch 45,000  of  46,094.    Elapsed: 12:31:40.
#   current average loss = 0.18873211899776038
#   Batch 45,500  of  46,094.    Elapsed: 12:40:00.
#   current average loss = 0.18748732914242913
#   Batch 46,000  of  46,094.    Elapsed: 12:48:20.
#   current average loss = 0.18634890301577917
#
#   Average training loss: 0.1861113428295841
#   Training epoch took: 12:49:53
#
# Running Validation...
#   Average validation loss: 0.06438649728138421
#   Accuracy: 0.9831425712612261
#   Validation took: 0:27:26
#
# ======== Epoch 2 / 10 ========
# Training...
#   Batch   500  of  46,094.    Elapsed: 0:08:11.
#   current average loss = 0.06600610079642502
#   Batch 1,000  of  46,094.    Elapsed: 0:16:17.
#   current average loss = 0.067710450602739
#   Batch 1,500  of  46,094.    Elapsed: 0:24:23.
#   current average loss = 0.06737658379823551
#   Batch 2,000  of  46,094.    Elapsed: 0:32:29.
#   current average loss = 0.06834925241265591
#   Batch 2,500  of  46,094.    Elapsed: 0:40:34.
#   current average loss = 0.06779653334846371
#   Batch 3,000  of  46,094.    Elapsed: 0:48:39.
#   current average loss = 0.06739908037057224
#   Batch 3,500  of  46,094.    Elapsed: 0:56:44.
#   current average loss = 0.06702504538822021
#   Batch 4,000  of  46,094.    Elapsed: 1:04:49.
#   current average loss = 0.0669573110363126
#   Batch 4,500  of  46,094.    Elapsed: 1:12:56.
#   current average loss = 0.06726124125186794
#   Batch 5,000  of  46,094.    Elapsed: 1:21:01.
#   current average loss = 0.0676064525375201
#   Batch 5,500  of  46,094.    Elapsed: 1:29:05.
#   current average loss = 0.06802782215980749
#   Batch 6,000  of  46,094.    Elapsed: 1:37:10.
#   current average loss = 0.06735309553872502
#   Batch 6,500  of  46,094.    Elapsed: 1:45:15.
#   current average loss = 0.06712248146309642
#   Batch 7,000  of  46,094.    Elapsed: 1:53:20.
#   current average loss = 0.0665084457776767
#   Batch 7,500  of  46,094.    Elapsed: 2:01:25.
#   current average loss = 0.0661588221374744
#   Batch 8,000  of  46,094.    Elapsed: 2:09:30.
#   current average loss = 0.06603622574409747
#   Batch 8,500  of  46,094.    Elapsed: 2:17:39.
#   current average loss = 0.0655817546011839
#   Batch 9,000  of  46,094.    Elapsed: 2:25:50.
#   current average loss = 0.06513466389038108
#   Batch 9,500  of  46,094.    Elapsed: 2:33:56.
#   current average loss = 0.06495597081610589
#   Batch 10,000  of  46,094.    Elapsed: 2:42:01.
#   current average loss = 0.06503336110758828
#   Batch 10,500  of  46,094.    Elapsed: 2:50:06.
#   current average loss = 0.06474494359866229
#   Batch 11,000  of  46,094.    Elapsed: 2:58:10.
#   current average loss = 0.06457212905820713
#   Batch 11,500  of  46,094.    Elapsed: 3:06:15.
#   current average loss = 0.0644995127829885
#   Batch 12,000  of  46,094.    Elapsed: 3:14:20.
#   current average loss = 0.06437038802495833
#   Batch 12,500  of  46,094.    Elapsed: 3:22:25.
#   current average loss = 0.06459816125090699
#   Batch 13,000  of  46,094.    Elapsed: 3:30:30.
#   current average loss = 0.06458345283075155
#   Batch 13,500  of  46,094.    Elapsed: 3:38:36.
#   current average loss = 0.06423309568948375
#   Batch 14,000  of  46,094.    Elapsed: 3:46:42.
#   current average loss = 0.06404606658668491
#   Batch 14,500  of  46,094.    Elapsed: 3:54:48.
#   current average loss = 0.06396280207971697
#   Batch 15,000  of  46,094.    Elapsed: 4:02:52.
#   current average loss = 0.06372870770159351
#   Batch 15,500  of  46,094.    Elapsed: 4:10:56.
#   current average loss = 0.06356801107078847
#   Batch 16,000  of  46,094.    Elapsed: 4:19:02.
#   current average loss = 0.0634521705643483
#   Batch 16,500  of  46,094.    Elapsed: 4:27:07.
#   current average loss = 0.06319646526353564
#   Batch 17,000  of  46,094.    Elapsed: 4:35:14.
#   current average loss = 0.06304232741632629
#   Batch 17,500  of  46,094.    Elapsed: 4:43:18.
#   current average loss = 0.06270844846674924
#   Batch 18,000  of  46,094.    Elapsed: 4:51:22.
#   current average loss = 0.06258848651381736
#   Batch 18,500  of  46,094.    Elapsed: 4:59:26.
#   current average loss = 0.06244475702821935
#   Batch 19,000  of  46,094.    Elapsed: 5:07:32.
#   current average loss = 0.06227482875514895
#   Batch 19,500  of  46,094.    Elapsed: 5:15:37.
#   current average loss = 0.06219609201636363
#   Batch 20,000  of  46,094.    Elapsed: 5:23:44.
#   current average loss = 0.0619362224911456
#   Batch 20,500  of  46,094.    Elapsed: 5:31:50.
#   current average loss = 0.061866560937359746
#   Batch 21,000  of  46,094.    Elapsed: 5:39:56.
#   current average loss = 0.06171556978954911
#   Batch 21,500  of  46,094.    Elapsed: 5:48:01.
#   current average loss = 0.061460217332105334
#   Batch 22,000  of  46,094.    Elapsed: 5:56:08.
#   current average loss = 0.06129993803509768
#   Batch 22,500  of  46,094.    Elapsed: 6:04:15.
#   current average loss = 0.06116975500375783
#   Batch 23,000  of  46,094.    Elapsed: 6:12:22.
#   current average loss = 0.060927550814726956
#   Batch 23,500  of  46,094.    Elapsed: 6:20:28.
#   current average loss = 0.06067525377517016
#   Batch 24,000  of  46,094.    Elapsed: 6:28:33.
#   current average loss = 0.06056931619787125
#   Batch 24,500  of  46,094.    Elapsed: 6:36:39.
#   current average loss = 0.060345344243252205
#   Batch 25,000  of  46,094.    Elapsed: 6:44:44.
#   current average loss = 0.06009162846203544
#   Batch 25,500  of  46,094.    Elapsed: 6:52:50.
#   current average loss = 0.059948576964691906
#   Batch 26,000  of  46,094.    Elapsed: 7:00:55.
#   current average loss = 0.05969888146957573
#   Batch 26,500  of  46,094.    Elapsed: 7:09:01.
#   current average loss = 0.05952833357559657
#   Batch 27,000  of  46,094.    Elapsed: 7:17:07.
#   current average loss = 0.05930458548645536
#   Batch 27,500  of  46,094.    Elapsed: 7:25:13.
#   current average loss = 0.05916476956061405
#   Batch 28,000  of  46,094.    Elapsed: 7:33:19.
#   current average loss = 0.059041640369104115
#   Batch 28,500  of  46,094.    Elapsed: 7:41:26.
#   current average loss = 0.05891175484117105
#   Batch 29,000  of  46,094.    Elapsed: 7:49:34.
#   current average loss = 0.058741285329419045
#   Batch 29,500  of  46,094.    Elapsed: 7:57:40.
#   current average loss = 0.05855107943045843
#   Batch 30,000  of  46,094.    Elapsed: 8:05:48.
#   current average loss = 0.05840419272088293
#   Batch 30,500  of  46,094.    Elapsed: 8:13:53.
#   current average loss = 0.05808012676247948
#   Batch 31,000  of  46,094.    Elapsed: 8:21:59.
#   current average loss = 0.05788552571169109
#   Batch 31,500  of  46,094.    Elapsed: 8:30:04.
#   current average loss = 0.05773849929847197
#   Batch 32,000  of  46,094.    Elapsed: 8:38:11.
#   current average loss = 0.05760891230646269
#   Batch 32,500  of  46,094.    Elapsed: 8:46:17.
#   current average loss = 0.057468962162012534
#   Batch 33,000  of  46,094.    Elapsed: 8:54:22.
#   current average loss = 0.05727494042209108
#   Batch 33,500  of  46,094.    Elapsed: 9:02:27.
#   current average loss = 0.057144648961150006
#   Batch 34,000  of  46,094.    Elapsed: 9:10:33.
#   current average loss = 0.05700922468867033
#   Batch 34,500  of  46,094.    Elapsed: 9:18:38.
#   current average loss = 0.05682740788908595
#   Batch 35,000  of  46,094.    Elapsed: 9:26:43.
#   current average loss = 0.056658674445786684
#   Batch 35,500  of  46,094.    Elapsed: 9:34:49.
#   current average loss = 0.05638619141539337
#   Batch 36,000  of  46,094.    Elapsed: 9:42:54.
#   current average loss = 0.056292076881793544
#   Batch 36,500  of  46,094.    Elapsed: 9:50:58.
#   current average loss = 0.056099143071400424
#   Batch 37,000  of  46,094.    Elapsed: 9:59:02.
#   current average loss = 0.05596005894078032
#   Batch 37,500  of  46,094.    Elapsed: 10:07:06.
#   current average loss = 0.05579858166850725
#   Batch 38,000  of  46,094.    Elapsed: 10:15:10.
#   current average loss = 0.05559104386159503
#   Batch 38,500  of  46,094.    Elapsed: 10:23:16.
#   current average loss = 0.055406531427944494
#   Batch 39,000  of  46,094.    Elapsed: 10:31:20.
#   current average loss = 0.055276629136107286
#   Batch 39,500  of  46,094.    Elapsed: 10:39:26.
#   current average loss = 0.05519158161026298
#   Batch 40,000  of  46,094.    Elapsed: 10:47:30.
#   current average loss = 0.05503682512002497
#   Batch 40,500  of  46,094.    Elapsed: 10:55:36.
#   current average loss = 0.054857839664172785
#   Batch 41,000  of  46,094.    Elapsed: 11:03:42.
#   current average loss = 0.054669142743217755
#   Batch 41,500  of  46,094.    Elapsed: 11:11:47.
#   current average loss = 0.05452871523957312
#   Batch 42,000  of  46,094.    Elapsed: 11:19:54.
#   current average loss = 0.05436408282584212
#   Batch 42,500  of  46,094.    Elapsed: 11:27:59.
#   current average loss = 0.054278060767984936
#   Batch 43,000  of  46,094.    Elapsed: 11:36:04.
#   current average loss = 0.054115120612926254
#   Batch 43,500  of  46,094.    Elapsed: 11:44:09.
#   current average loss = 0.05396399882595376
#   Batch 44,000  of  46,094.    Elapsed: 11:52:15.
#   current average loss = 0.05386819957132477
#   Batch 44,500  of  46,094.    Elapsed: 12:00:20.
#   current average loss = 0.05369499149301955
#   Batch 45,000  of  46,094.    Elapsed: 12:08:24.
#   current average loss = 0.05358809171523438
#   Batch 45,500  of  46,094.    Elapsed: 12:16:32.
#   current average loss = 0.05346374924572696
#   Batch 46,000  of  46,094.    Elapsed: 12:24:37.
#   current average loss = 0.05330658898138941
#
#   Average training loss: 0.05327241120907275
#   Training epoch took: 12:26:07
#
# Running Validation...
#   Average validation loss: 0.03243150836366476
#   Accuracy: 0.9912143693869582
#   Validation took: 0:27:17
#
# ======== Epoch 3 / 10 ========
# Training...
#   Batch   500  of  46,094.    Elapsed: 0:08:04.
#   current average loss = 0.03377708706547856
#   Batch 1,000  of  46,094.    Elapsed: 0:16:09.
#   current average loss = 0.03534176722467237
#   Batch 1,500  of  46,094.    Elapsed: 0:24:15.
#   current average loss = 0.03496521683974425
#   Batch 2,000  of  46,094.    Elapsed: 0:32:20.
#   current average loss = 0.03406107068842175
#   Batch 2,500  of  46,094.    Elapsed: 0:40:24.
#   current average loss = 0.034066197058446414
#   Batch 3,000  of  46,094.    Elapsed: 0:48:29.
#   current average loss = 0.03470912014772936
#   Batch 3,500  of  46,094.    Elapsed: 0:56:35.
#   current average loss = 0.03470172343446029
#   Batch 4,000  of  46,094.    Elapsed: 1:04:39.
#   current average loss = 0.03470183493014429
#   Batch 4,500  of  46,094.    Elapsed: 1:12:43.
#   current average loss = 0.03424200972974682
#   Batch 5,000  of  46,094.    Elapsed: 1:20:48.
#   current average loss = 0.035243230132848836
#   Batch 5,500  of  46,094.    Elapsed: 1:28:54.
#   current average loss = 0.035141837289252596
#   Batch 6,000  of  46,094.    Elapsed: 1:36:57.
#   current average loss = 0.03521184802910769
#   Batch 6,500  of  46,094.    Elapsed: 1:45:01.
#   current average loss = 0.0349251731666199
#   Batch 7,000  of  46,094.    Elapsed: 1:53:07.
#   current average loss = 0.03475455998150885
#   Batch 7,500  of  46,094.    Elapsed: 2:01:11.
#   current average loss = 0.03450861112300578
#   Batch 8,000  of  46,094.    Elapsed: 2:09:18.
#   current average loss = 0.034523315312249905
#   Batch 8,500  of  46,094.    Elapsed: 2:17:24.
#   current average loss = 0.03470071804722615
#   Batch 9,000  of  46,094.    Elapsed: 2:25:31.
#   current average loss = 0.03461637887981447
#   Batch 9,500  of  46,094.    Elapsed: 2:33:36.
#   current average loss = 0.03456008093889556
#   Batch 10,000  of  46,094.    Elapsed: 2:41:42.
#   current average loss = 0.0345664349952127
#   Batch 10,500  of  46,094.    Elapsed: 2:49:45.
#   current average loss = 0.034646960985109866
#   Batch 11,000  of  46,094.    Elapsed: 2:57:50.
#   current average loss = 0.03457281231948549
#   Batch 11,500  of  46,094.    Elapsed: 3:05:55.
#   current average loss = 0.03454452143135037
#   Batch 12,000  of  46,094.    Elapsed: 3:13:59.
#   current average loss = 0.03483619195587047
#   Batch 12,500  of  46,094.    Elapsed: 3:22:04.
#   current average loss = 0.034855513960892856
#   Batch 13,000  of  46,094.    Elapsed: 3:30:09.
#   current average loss = 0.03489845641240922
#   Batch 13,500  of  46,094.    Elapsed: 3:38:13.
#   current average loss = 0.03492623334845255
#   Batch 14,000  of  46,094.    Elapsed: 3:46:18.
#   current average loss = 0.03504466530216736
#   Batch 14,500  of  46,094.    Elapsed: 3:54:21.
#   current average loss = 0.0350940992686326
#   Batch 15,000  of  46,094.    Elapsed: 4:02:26.
#   current average loss = 0.03501374614279072
#   Batch 15,500  of  46,094.    Elapsed: 4:10:31.
#   current average loss = 0.03496965747966451
#   Batch 16,000  of  46,094.    Elapsed: 4:18:34.
#   current average loss = 0.03503860935759826
#   Batch 16,500  of  46,094.    Elapsed: 4:26:39.
#   current average loss = 0.03504148389071854
#   Batch 17,000  of  46,094.    Elapsed: 4:34:43.
#   current average loss = 0.035003263036823815
#   Batch 17,500  of  46,094.    Elapsed: 4:42:46.
#   current average loss = 0.03508491277955369
#   Batch 18,000  of  46,094.    Elapsed: 4:50:49.
#   current average loss = 0.03502868101621425
#   Batch 18,500  of  46,094.    Elapsed: 4:58:56.
#   current average loss = 0.03494725734381614
#   Batch 19,000  of  46,094.    Elapsed: 5:06:59.
#   current average loss = 0.034824823223128895
#   Batch 19,500  of  46,094.    Elapsed: 5:15:03.
#   current average loss = 0.03489304596857218
#   Batch 20,000  of  46,094.    Elapsed: 5:23:07.
#   current average loss = 0.034921669921907414
#   Batch 20,500  of  46,094.    Elapsed: 5:31:11.
#   current average loss = 0.034929740145814035
#   Batch 21,000  of  46,094.    Elapsed: 5:39:17.
#   current average loss = 0.03491089751032026
#   Batch 21,500  of  46,094.    Elapsed: 5:47:21.
#   current average loss = 0.03488395529239422
#   Batch 22,000  of  46,094.    Elapsed: 5:55:27.
#   current average loss = 0.03479527240530098
#   Batch 22,500  of  46,094.    Elapsed: 6:03:31.
#   current average loss = 0.03466797986576243
#   Batch 23,000  of  46,094.    Elapsed: 6:11:34.
#   current average loss = 0.03467269242346969
#   Batch 23,500  of  46,094.    Elapsed: 6:19:38.
#   current average loss = 0.03452732713527679
#   Batch 24,000  of  46,094.    Elapsed: 6:27:44.
#   current average loss = 0.034488910720075185
#   Batch 24,500  of  46,094.    Elapsed: 6:35:48.
#   current average loss = 0.034380885110770074
#   Batch 25,000  of  46,094.    Elapsed: 6:43:53.
#   current average loss = 0.034276664294884976
#   Batch 25,500  of  46,094.    Elapsed: 6:51:56.
#   current average loss = 0.03424364611411204
#   Batch 26,000  of  46,094.    Elapsed: 6:59:59.
#   current average loss = 0.034137967268468856
#   Batch 26,500  of  46,094.    Elapsed: 7:08:04.
#   current average loss = 0.034048522889430284
#   Batch 27,000  of  46,094.    Elapsed: 7:16:08.
#   current average loss = 0.03407787930105338
#   Batch 27,500  of  46,094.    Elapsed: 7:24:13.
#   current average loss = 0.0341258531549034
#   Batch 28,000  of  46,094.    Elapsed: 7:32:17.
#   current average loss = 0.03402174642692599
#   Batch 28,500  of  46,094.    Elapsed: 7:40:22.
#   current average loss = 0.03396834028504287
#   Batch 29,000  of  46,094.    Elapsed: 7:48:25.
#   current average loss = 0.03391779948935386
#   Batch 29,500  of  46,094.    Elapsed: 7:56:30.
#   current average loss = 0.03383788744413249
#   Batch 30,000  of  46,094.    Elapsed: 8:04:34.
#   current average loss = 0.033773244942443124
#   Batch 30,500  of  46,094.    Elapsed: 8:12:39.
#   current average loss = 0.03368679656930479
#   Batch 31,000  of  46,094.    Elapsed: 8:20:43.
#   current average loss = 0.03362660474652829
#   Batch 31,500  of  46,094.    Elapsed: 8:28:46.
#   current average loss = 0.03350937017074212
#   Batch 32,000  of  46,094.    Elapsed: 8:36:52.
#   current average loss = 0.03348961031626015
#   Batch 32,500  of  46,094.    Elapsed: 8:44:55.
#   current average loss = 0.03339854700759002
#   Batch 33,000  of  46,094.    Elapsed: 8:53:01.
#   current average loss = 0.03336161090272215
#   Batch 33,500  of  46,094.    Elapsed: 9:01:05.
#   current average loss = 0.03331776922502479
#   Batch 34,000  of  46,094.    Elapsed: 9:09:08.
#   current average loss = 0.03323344668063959
#   Batch 34,500  of  46,094.    Elapsed: 9:17:12.
#   current average loss = 0.03311318790827605
#   Batch 35,000  of  46,094.    Elapsed: 9:25:15.
#   current average loss = 0.03304246059932484
#   Batch 35,500  of  46,094.    Elapsed: 9:33:20.
#   current average loss = 0.03301766099682993
#   Batch 36,000  of  46,094.    Elapsed: 9:41:24.
#   current average loss = 0.03297688447336592
#   Batch 36,500  of  46,094.    Elapsed: 9:49:28.
#   current average loss = 0.03287158661546191
#   Batch 37,000  of  46,094.    Elapsed: 9:57:32.
#   current average loss = 0.0328768274158515
#   Batch 37,500  of  46,094.    Elapsed: 10:05:36.
#   current average loss = 0.03283405258456963
#   Batch 38,000  of  46,094.    Elapsed: 10:13:40.
#   current average loss = 0.032780946522839305
#   Batch 38,500  of  46,094.    Elapsed: 10:21:46.
#   current average loss = 0.032770042202409824
#   Batch 39,000  of  46,094.    Elapsed: 10:29:50.
#   current average loss = 0.03273770584886388
#   Batch 39,500  of  46,094.    Elapsed: 10:37:54.
#   current average loss = 0.03267756866744301
#   Batch 40,000  of  46,094.    Elapsed: 10:45:57.
#   current average loss = 0.03265709445078137
#   Batch 40,500  of  46,094.    Elapsed: 10:54:02.
#   current average loss = 0.03259372003371903
#   Batch 41,000  of  46,094.    Elapsed: 11:02:06.
#   current average loss = 0.03254446825784216
#   Batch 41,500  of  46,094.    Elapsed: 11:10:10.
#   current average loss = 0.03245914917617816
#   Batch 42,000  of  46,094.    Elapsed: 11:18:14.
#   current average loss = 0.03239633762990473
#   Batch 42,500  of  46,094.    Elapsed: 11:26:18.
#   current average loss = 0.032327601832986094
#   Batch 43,000  of  46,094.    Elapsed: 11:34:23.
#   current average loss = 0.03227996220344552
#   Batch 43,500  of  46,094.    Elapsed: 11:42:25.
#   current average loss = 0.03220833976338569
#   Batch 44,000  of  46,094.    Elapsed: 11:50:29.
#   current average loss = 0.032153130171756854
#   Batch 44,500  of  46,094.    Elapsed: 11:58:33.
#   current average loss = 0.032108506101103315
#   Batch 45,000  of  46,094.    Elapsed: 12:06:37.
#   current average loss = 0.03203070258124119
#   Batch 45,500  of  46,094.    Elapsed: 12:14:41.
#   current average loss = 0.03200620814429591
#   Batch 46,000  of  46,094.    Elapsed: 12:22:45.
#   current average loss = 0.03192269174593386
#
#   Average training loss: 0.03191785456955981
#   Training epoch took: 12:24:15
#
# Running Validation...
#   Average validation loss: 0.02413356687710039
#   Accuracy: 0.9933314623194065
#   Validation took: 0:27:18
#
# ======== Epoch 4 / 10 ========
# Training...
#   Batch   500  of  46,094.    Elapsed: 0:08:06.
#   current average loss = 0.023157035647382144
#   Batch 1,000  of  46,094.    Elapsed: 0:16:11.
#   current average loss = 0.023948085509844532
#   Batch 1,500  of  46,094.    Elapsed: 0:24:15.
#   current average loss = 0.02250998369788067
#   Batch 2,000  of  46,094.    Elapsed: 0:32:20.
#   current average loss = 0.02285436133993335
#   Batch 2,500  of  46,094.    Elapsed: 0:40:25.
#   current average loss = 0.022197425389938873
#   Batch 3,000  of  46,094.    Elapsed: 0:48:28.
#   current average loss = 0.022260693358469627
#   Batch 3,500  of  46,094.    Elapsed: 0:56:31.
#   current average loss = 0.022591453330653686
#   Batch 4,000  of  46,094.    Elapsed: 1:04:37.
#   current average loss = 0.022656602944743098
#   Batch 4,500  of  46,094.    Elapsed: 1:12:41.
#   current average loss = 0.023314093046809526
#   Batch 5,000  of  46,094.    Elapsed: 1:20:45.
#   current average loss = 0.023694258120713494
#   Batch 5,500  of  46,094.    Elapsed: 1:28:49.
#   current average loss = 0.023685168052029356
#   Batch 6,000  of  46,094.    Elapsed: 1:36:53.
#   current average loss = 0.023749444294198837
#   Batch 6,500  of  46,094.    Elapsed: 1:44:57.
#   current average loss = 0.024026258223971617
#   Batch 7,000  of  46,094.    Elapsed: 1:53:00.
#   current average loss = 0.024006827596371294
#   Batch 7,500  of  46,094.    Elapsed: 2:01:04.
#   current average loss = 0.024212264639737743
#   Batch 8,000  of  46,094.    Elapsed: 2:09:07.
#   current average loss = 0.023831173970441343
#   Batch 8,500  of  46,094.    Elapsed: 2:17:12.
#   current average loss = 0.023851663914466317
#   Batch 9,000  of  46,094.    Elapsed: 2:25:17.
#   current average loss = 0.02391132749654207
#   Batch 9,500  of  46,094.    Elapsed: 2:33:20.
#   current average loss = 0.023911386319946982
#   Batch 10,000  of  46,094.    Elapsed: 2:41:24.
#   current average loss = 0.023754210488917307
#   Batch 10,500  of  46,094.    Elapsed: 2:49:27.
#   current average loss = 0.023818669795665343
#   Batch 11,000  of  46,094.    Elapsed: 2:57:31.
#   current average loss = 0.023737967580503623
#   Batch 11,500  of  46,094.    Elapsed: 3:05:35.
#   current average loss = 0.023817667598738056
#   Batch 12,000  of  46,094.    Elapsed: 3:13:38.
#   current average loss = 0.02392724091014376
#   Batch 12,500  of  46,094.    Elapsed: 3:21:42.
#   current average loss = 0.02398452240681043
#   Batch 13,000  of  46,094.    Elapsed: 3:29:45.
#   current average loss = 0.02395390250766104
#   Batch 13,500  of  46,094.    Elapsed: 3:37:49.
#   current average loss = 0.023865718131796138
#   Batch 14,000  of  46,094.    Elapsed: 3:45:53.
#   current average loss = 0.02388579781957833
#   Batch 14,500  of  46,094.    Elapsed: 3:53:56.
#   current average loss = 0.023797684941197075
#   Batch 15,000  of  46,094.    Elapsed: 4:02:00.
#   current average loss = 0.023696530888529983
#   Batch 15,500  of  46,094.    Elapsed: 4:10:04.
#   current average loss = 0.023677563468673227
#   Batch 16,000  of  46,094.    Elapsed: 4:18:08.
#   current average loss = 0.023786512144820905
#   Batch 16,500  of  46,094.    Elapsed: 4:26:14.
#   current average loss = 0.023877968149266633
#   Batch 17,000  of  46,094.    Elapsed: 4:34:20.
#   current average loss = 0.023790722212650935
#   Batch 17,500  of  46,094.    Elapsed: 4:42:24.
#   current average loss = 0.023691256779850456
#   Batch 18,000  of  46,094.    Elapsed: 4:50:27.
#   current average loss = 0.023523579668691126
#   Batch 18,500  of  46,094.    Elapsed: 4:58:32.
#   current average loss = 0.0235040724296639
#   Batch 19,000  of  46,094.    Elapsed: 5:06:36.
#   current average loss = 0.023504634842640083
#   Batch 19,500  of  46,094.    Elapsed: 5:14:40.
#   current average loss = 0.02363317198868446
#   Batch 20,000  of  46,094.    Elapsed: 5:22:43.
#   current average loss = 0.023579883060220436
#   Batch 20,500  of  46,094.    Elapsed: 5:30:49.
#   current average loss = 0.0234888625958596
#   Batch 21,000  of  46,094.    Elapsed: 5:38:53.
#   current average loss = 0.02345794136781868
#   Batch 21,500  of  46,094.    Elapsed: 5:46:57.
#   current average loss = 0.023430485152301117
#   Batch 22,000  of  46,094.    Elapsed: 5:55:00.
#   current average loss = 0.023300829428678796
#   Batch 22,500  of  46,094.    Elapsed: 6:03:03.
#   current average loss = 0.023331380697659512
#   Batch 23,000  of  46,094.    Elapsed: 6:11:06.
#   current average loss = 0.023235268519761317
#   Batch 23,500  of  46,094.    Elapsed: 6:19:11.
#   current average loss = 0.02325378297612158
#   Batch 24,000  of  46,094.    Elapsed: 6:27:15.
#   current average loss = 0.02326316842060161
#   Batch 24,500  of  46,094.    Elapsed: 6:35:18.
#   current average loss = 0.02318574837296071
#   Batch 25,000  of  46,094.    Elapsed: 6:43:22.
#   current average loss = 0.02312209724051667
#   Batch 25,500  of  46,094.    Elapsed: 6:51:26.
#   current average loss = 0.02305275270718259
#   Batch 26,000  of  46,094.    Elapsed: 6:59:31.
#   current average loss = 0.023031268212530587
#   Batch 26,500  of  46,094.    Elapsed: 7:07:34.
#   current average loss = 0.022988040831241136
#   Batch 27,000  of  46,094.    Elapsed: 7:15:38.
#   current average loss = 0.022954772926598404
#   Batch 27,500  of  46,094.    Elapsed: 7:23:42.
#   current average loss = 0.022974429169226377
#   Batch 28,000  of  46,094.    Elapsed: 7:31:46.
#   current average loss = 0.022910677410297012
#   Batch 28,500  of  46,094.    Elapsed: 7:39:51.
#   current average loss = 0.022893839710708817
#   Batch 29,000  of  46,094.    Elapsed: 7:47:55.
#   current average loss = 0.022928732856070225
#   Batch 29,500  of  46,094.    Elapsed: 7:55:59.
#   current average loss = 0.02300103860087053
#   Batch 30,000  of  46,094.    Elapsed: 8:04:03.
#   current average loss = 0.022999321120104832
#   Batch 30,500  of  46,094.    Elapsed: 8:12:07.
#   current average loss = 0.02298511329296573
#   Batch 31,000  of  46,094.    Elapsed: 8:20:11.
#   current average loss = 0.022938659399598868
#   Batch 31,500  of  46,094.    Elapsed: 8:28:14.
#   current average loss = 0.022901473467656152
#   Batch 32,000  of  46,094.    Elapsed: 8:36:18.
#   current average loss = 0.022909026375789322
#   Batch 32,500  of  46,094.    Elapsed: 8:44:21.
#   current average loss = 0.022887132700917797
#   Batch 33,000  of  46,094.    Elapsed: 8:52:25.
#   current average loss = 0.022850013927249387
#   Batch 33,500  of  46,094.    Elapsed: 9:00:30.
#   current average loss = 0.02275658724043219
#   Batch 34,000  of  46,094.    Elapsed: 9:08:33.
#   current average loss = 0.02272111285237952
#   Batch 34,500  of  46,094.    Elapsed: 9:16:36.
#   current average loss = 0.022736152013885208
#   Batch 35,000  of  46,094.    Elapsed: 9:24:41.
#   current average loss = 0.022705622164306
#   Batch 35,500  of  46,094.    Elapsed: 9:32:45.
#   current average loss = 0.022675974060059802
#   Batch 36,000  of  46,094.    Elapsed: 9:40:49.
#   current average loss = 0.022606908850986707
#   Batch 36,500  of  46,094.    Elapsed: 9:48:53.
#   current average loss = 0.022607344109733463
#   Batch 37,000  of  46,094.    Elapsed: 9:56:57.
#   current average loss = 0.022618271769158052
#   Batch 38,000  of  46,094.    Elapsed: 10:13:05.
#   current average loss = 0.022605720232340087
#   Batch 38,500  of  46,094.    Elapsed: 10:21:10.
#   current average loss = 0.022611596524168828
#   Batch 39,000  of  46,094.    Elapsed: 10:29:13.
#   current average loss = 0.022601638334281
#   Batch 39,500  of  46,094.    Elapsed: 10:37:17.
#   current average loss = 0.022527916949106504
#   Batch 40,000  of  46,094.    Elapsed: 10:45:21.
#   current average loss = 0.022570215889231623
#   Batch 40,500  of  46,094.    Elapsed: 10:53:24.
#   current average loss = 0.022523339303204628
#   Batch 41,000  of  46,094.    Elapsed: 11:01:30.
#   current average loss = 0.022470130439498727
#   Batch 41,500  of  46,094.    Elapsed: 11:09:34.
#   current average loss = 0.022425726192800945
#   Batch 42,000  of  46,094.    Elapsed: 11:17:38.
#   current average loss = 0.022363231257013467
#   Batch 42,500  of  46,094.    Elapsed: 11:25:42.
#   current average loss = 0.022330585770574844
#   Batch 43,000  of  46,094.    Elapsed: 11:33:47.
#   current average loss = 0.022311586253842993
#   Batch 43,500  of  46,094.    Elapsed: 11:41:52.
#   current average loss = 0.02227186954451421
#   Batch 44,000  of  46,094.    Elapsed: 11:49:57.
#   current average loss = 0.022244912590145677
#   Batch 44,500  of  46,094.    Elapsed: 11:58:01.
#   current average loss = 0.022246877407855657
#   Batch 45,000  of  46,094.    Elapsed: 12:06:05.
#   current average loss = 0.022196256559757686
#   Batch 45,500  of  46,094.    Elapsed: 12:14:12.
#   current average loss = 0.02217439906007776
#   Batch 46,000  of  46,094.    Elapsed: 12:22:16.
#   current average loss = 0.022180574657141613
#
#   Average training loss: 0.02217163563124244
#   Training epoch took: 12:23:47
#
# Running Validation...
#   Average validation loss: 0.016906572403533274
#   Accuracy: 0.99455168879344
#   Validation took: 0:27:18
#
# ======== Epoch 5 / 10 ========
# Training...
#   Batch   500  of  46,094.    Elapsed: 0:08:05.
#   current average loss = 0.013406639316006476
#   Batch 1,000  of  46,094.    Elapsed: 0:16:08.
#   current average loss = 0.015705597627627868
#   Batch 1,500  of  46,094.    Elapsed: 0:24:11.
#   current average loss = 0.01584590891256933
#   Batch 2,000  of  46,094.    Elapsed: 0:32:16.
#   current average loss = 0.0162513686078737
#   Batch 2,500  of  46,094.    Elapsed: 0:40:20.
#   current average loss = 0.016633001592099027
#   Batch 3,000  of  46,094.    Elapsed: 0:48:23.
#   current average loss = 0.017020732145369644
#   Batch 3,500  of  46,094.    Elapsed: 0:56:27.
#   current average loss = 0.017223256551117498
#   Batch 4,000  of  46,094.    Elapsed: 1:04:32.
#   current average loss = 0.016948528748977423
#   Batch 4,500  of  46,094.    Elapsed: 1:12:36.
#   current average loss = 0.017123112394618754
#   Batch 5,000  of  46,094.    Elapsed: 1:20:40.
#   current average loss = 0.01727114267540237
#   Batch 5,500  of  46,094.    Elapsed: 1:28:44.
#   current average loss = 0.017254210666623377
#   Batch 6,000  of  46,094.    Elapsed: 1:36:50.
#   current average loss = 0.017036829048051913
#   Batch 6,500  of  46,094.    Elapsed: 1:44:55.
#   current average loss = 0.016788365618573154
#   Batch 7,000  of  46,094.    Elapsed: 1:52:58.
#   current average loss = 0.016871266952806243
#   Batch 7,500  of  46,094.    Elapsed: 2:01:03.
#   current average loss = 0.016937181838981633
#   Batch 8,000  of  46,094.    Elapsed: 2:09:07.
#   current average loss = 0.017121497318399632
#   Batch 8,500  of  46,094.    Elapsed: 2:17:11.
#   current average loss = 0.017288674261075786
#   Batch 9,000  of  46,094.    Elapsed: 2:25:15.
#   current average loss = 0.017271518755906275
#   Batch 9,500  of  46,094.    Elapsed: 2:33:19.
#   current average loss = 0.017105845682972454
#   Batch 10,000  of  46,094.    Elapsed: 2:41:24.
#   current average loss = 0.0171371881477693
#   Batch 10,500  of  46,094.    Elapsed: 2:49:29.
#   current average loss = 0.017029183012090686
#   Batch 11,000  of  46,094.    Elapsed: 2:57:33.
#   current average loss = 0.01720616408587127
#   Batch 11,500  of  46,094.    Elapsed: 3:05:38.
#   current average loss = 0.01727800779462094
#   Batch 12,000  of  46,094.    Elapsed: 3:13:43.
#   current average loss = 0.017369900676199753
#   Batch 12,500  of  46,094.    Elapsed: 3:21:47.
#   current average loss = 0.017362981341081614
#   Batch 13,000  of  46,094.    Elapsed: 3:29:51.
#   current average loss = 0.017331824352554925
#   Batch 13,500  of  46,094.    Elapsed: 3:37:56.
#   current average loss = 0.017339332369027776
#   Batch 14,000  of  46,094.    Elapsed: 3:46:01.
#   current average loss = 0.01732446186686892
#   Batch 14,500  of  46,094.    Elapsed: 3:54:08.
#   current average loss = 0.017303799585649766
#   Batch 15,500  of  46,094.    Elapsed: 4:10:18.
#   current average loss = 0.0172870937258422
#   Batch 16,000  of  46,094.    Elapsed: 4:18:22.
#   current average loss = 0.01723875626811059
#   Batch 16,500  of  46,094.    Elapsed: 4:26:27.
#   current average loss = 0.017192582856371177
#   Batch 17,000  of  46,094.    Elapsed: 4:34:31.
#   current average loss = 0.017271454801653926
#   Batch 17,500  of  46,094.    Elapsed: 4:42:36.
#   current average loss = 0.017264123346752914
#   Batch 18,000  of  46,094.    Elapsed: 4:50:43.
#   current average loss = 0.017267988551683024
#   Batch 18,500  of  46,094.    Elapsed: 4:58:48.
#   current average loss = 0.01729205327308542
#   Batch 19,000  of  46,094.    Elapsed: 5:06:53.
#   current average loss = 0.017305330376195343
#   Batch 19,500  of  46,094.    Elapsed: 5:14:58.
#   current average loss = 0.01734545365779027
#   Batch 20,000  of  46,094.    Elapsed: 5:23:01.
#   current average loss = 0.017283633313820157
#   Batch 20,500  of  46,094.    Elapsed: 5:31:06.
#   current average loss = 0.01725958640831205
#   Batch 21,000  of  46,094.    Elapsed: 5:39:09.
#   current average loss = 0.017205984921146368
#   Batch 21,500  of  46,094.    Elapsed: 5:47:13.
#   current average loss = 0.017192167371352995
#   Batch 22,000  of  46,094.    Elapsed: 5:55:17.
#   current average loss = 0.01714870352221012
#   Batch 22,500  of  46,094.    Elapsed: 6:03:20.
#   current average loss = 0.017070269553026284
#   Batch 23,000  of  46,094.    Elapsed: 6:11:24.
#   current average loss = 0.017112773128904694
#   Batch 23,500  of  46,094.    Elapsed: 6:19:28.
#   current average loss = 0.017116427392935604
#   Batch 24,000  of  46,094.    Elapsed: 6:27:35.
#   current average loss = 0.01713594165393412
#   Batch 24,500  of  46,094.    Elapsed: 6:35:39.
#   current average loss = 0.01712313637143345
#   Batch 25,000  of  46,094.    Elapsed: 6:43:43.
#   current average loss = 0.017080467370758416
#   Batch 25,500  of  46,094.    Elapsed: 6:51:47.
#   current average loss = 0.017095289929842192
#   Batch 26,000  of  46,094.    Elapsed: 6:59:51.
#   current average loss = 0.01701930655765955
#   Batch 26,500  of  46,094.    Elapsed: 7:07:55.
#   current average loss = 0.01700286357175506
#   Batch 27,000  of  46,094.    Elapsed: 7:16:00.
#   current average loss = 0.017024274637648582
#   Batch 27,500  of  46,094.    Elapsed: 7:24:03.
#   current average loss = 0.017040656703611205
#   Batch 28,000  of  46,094.    Elapsed: 7:32:08.
#   current average loss = 0.017049932414133894
#   Batch 28,500  of  46,094.    Elapsed: 7:40:12.
#   current average loss = 0.016988734249168677
#   Batch 29,000  of  46,094.    Elapsed: 7:48:15.
#   current average loss = 0.0170164889193851
#   Batch 29,500  of  46,094.    Elapsed: 7:56:19.
#   current average loss = 0.017008156552971356
#   Batch 30,000  of  46,094.    Elapsed: 8:04:24.
#   current average loss = 0.01692554072841146
#   Batch 30,500  of  46,094.    Elapsed: 8:12:28.
#   current average loss = 0.01699164782109366
#   Batch 31,000  of  46,094.    Elapsed: 8:20:31.
#   current average loss = 0.0169542149918045
#   Batch 31,500  of  46,094.    Elapsed: 8:28:35.
#   current average loss = 0.016946855733192413
#   Batch 32,000  of  46,094.    Elapsed: 8:36:41.
#   current average loss = 0.016978701326026965
#   Batch 32,500  of  46,094.    Elapsed: 8:44:44.
#   current average loss = 0.016948554242182525
#   Batch 33,000  of  46,094.    Elapsed: 8:52:49.
#   current average loss = 0.01692145025176703
#   Batch 33,500  of  46,094.    Elapsed: 9:00:54.
#   current average loss = 0.016856696222321832
#   Batch 34,000  of  46,094.    Elapsed: 9:09:00.
#   current average loss = 0.016863405845211298
#   Batch 34,500  of  46,094.    Elapsed: 9:17:05.
#   current average loss = 0.016833106087321262
#   Batch 35,000  of  46,094.    Elapsed: 9:25:09.
#   current average loss = 0.016851408787568654
#   Batch 35,500  of  46,094.    Elapsed: 9:33:15.
#   current average loss = 0.016844819024388235
#   Batch 36,000  of  46,094.    Elapsed: 9:41:21.
#   current average loss = 0.01685256093888802
#   Batch 36,500  of  46,094.    Elapsed: 9:49:26.
#   current average loss = 0.01684396714987626
#   Batch 37,000  of  46,094.    Elapsed: 9:57:30.
#   current average loss = 0.016805204807150673
#   Batch 37,500  of  46,094.    Elapsed: 10:05:38.
#   current average loss = 0.01680119942110973
#   Batch 38,000  of  46,094.    Elapsed: 10:13:43.
#   current average loss = 0.016818104503517756
#   Batch 38,500  of  46,094.    Elapsed: 10:21:48.
#   current average loss = 0.0168036899234579
#   Batch 39,000  of  46,094.    Elapsed: 10:29:53.
#   current average loss = 0.016747285200328733
#   Batch 39,500  of  46,094.    Elapsed: 10:37:58.
#   current average loss = 0.016705129343056024
#   Batch 40,000  of  46,094.    Elapsed: 10:46:03.
#   current average loss = 0.016702915831151948
#   Batch 40,500  of  46,094.    Elapsed: 10:54:08.
#   current average loss = 0.016741550432304877
#   Batch 41,000  of  46,094.    Elapsed: 11:02:14.
#   current average loss = 0.016728807911998114
#   Batch 41,500  of  46,094.    Elapsed: 11:10:19.
#   current average loss = 0.01670526815798965
#   Batch 42,000  of  46,094.    Elapsed: 11:18:25.
#   current average loss = 0.016683488741999444
#   Batch 42,500  of  46,094.    Elapsed: 11:26:31.
#   current average loss = 0.016654592528892852
#   Batch 43,000  of  46,094.    Elapsed: 11:34:36.
#   current average loss = 0.016649696072286703
#   Batch 43,500  of  46,094.    Elapsed: 11:42:41.
#   current average loss = 0.016633340794595188
#   Batch 44,000  of  46,094.    Elapsed: 11:50:46.
#   current average loss = 0.016617895608343588
#   Batch 44,500  of  46,094.    Elapsed: 11:58:51.
#   current average loss = 0.016593132332098443
#   Batch 45,000  of  46,094.    Elapsed: 12:06:57.
#   current average loss = 0.01657803784700409
#   Batch 45,500  of  46,094.    Elapsed: 12:15:02.
#   current average loss = 0.016571030227400335
#   Batch 46,000  of  46,094.    Elapsed: 12:23:09.
#   current average loss = 0.016617222549727518
#
#   Average training loss: 0.0166034384856979
#   Training epoch took: 12:24:39
#
# Running Validation...
#   Average validation loss: 0.013255006559023069
#   Accuracy: 0.9951801054275674
#   Validation took: 0:27:17
#
# ======== Epoch 6 / 10 ========
# Training...
#   Batch   500  of  46,094.    Elapsed: 0:08:04.
#   current average loss = 0.013790827299577358
#   Batch 1,000  of  46,094.    Elapsed: 0:16:07.
#   current average loss = 0.01285392229106219
#   Batch 1,500  of  46,094.    Elapsed: 0:24:12.
#   current average loss = 0.012503321125661992
#   Batch 2,000  of  46,094.    Elapsed: 0:32:17.
#   current average loss = 0.012378108790686383
#   Batch 2,500  of  46,094.    Elapsed: 0:40:23.
#   current average loss = 0.012153710698572831
#   Batch 3,000  of  46,094.    Elapsed: 0:48:29.
#   current average loss = 0.012010266294959365
#   Batch 3,500  of  46,094.    Elapsed: 0:56:33.
#   current average loss = 0.012086490472208035
#   Batch 4,000  of  46,094.    Elapsed: 1:04:37.
#   current average loss = 0.011821079305504554
#   Batch 4,500  of  46,094.    Elapsed: 1:12:40.
#   current average loss = 0.012376075739585456
#   Batch 5,000  of  46,094.    Elapsed: 1:20:44.
#   current average loss = 0.01259282049769463
#   Batch 5,500  of  46,094.    Elapsed: 1:28:48.
#   current average loss = 0.012679032634980103
#   Batch 6,000  of  46,094.    Elapsed: 1:36:52.
#   current average loss = 0.012682654264995107
#   Batch 6,500  of  46,094.    Elapsed: 1:44:56.
#   current average loss = 0.012612138644965923
#   Batch 7,000  of  46,094.    Elapsed: 1:52:59.
#   current average loss = 0.01250988858465358
#   Batch 7,500  of  46,094.    Elapsed: 2:01:04.
#   current average loss = 0.012524973339045634
#   Batch 8,000  of  46,094.    Elapsed: 2:09:08.
#   current average loss = 0.012557764773401118
#   Batch 8,500  of  46,094.    Elapsed: 2:17:12.
#   current average loss = 0.012663815514886129
#   Batch 9,000  of  46,094.    Elapsed: 2:25:17.
#   current average loss = 0.012657504318936339
#   Batch 9,500  of  46,094.    Elapsed: 2:33:21.
#   current average loss = 0.01290774007414563
#   Batch 10,000  of  46,094.    Elapsed: 2:41:25.
#   current average loss = 0.012932606217190277
#   Batch 10,500  of  46,094.    Elapsed: 2:49:28.
#   current average loss = 0.012994988019453861
#   Batch 11,000  of  46,094.    Elapsed: 2:57:32.
#   current average loss = 0.013074796744154231
#   Batch 11,500  of  46,094.    Elapsed: 3:05:36.
#   current average loss = 0.012985356752232648
#   Batch 12,000  of  46,094.    Elapsed: 3:13:40.
#   current average loss = 0.01287641971003806
#   Batch 12,500  of  46,094.    Elapsed: 3:21:49.
#   current average loss = 0.012916810039327393
#   Batch 13,000  of  46,094.    Elapsed: 3:30:00.
#   current average loss = 0.012828651153428907
#   Batch 13,500  of  46,094.    Elapsed: 3:38:10.
#   current average loss = 0.012849224763952845
#   Batch 14,000  of  46,094.    Elapsed: 3:46:20.
#   current average loss = 0.01288013975600487
#   Batch 14,500  of  46,094.    Elapsed: 3:54:29.
#   current average loss = 0.012869222085420852
#   Batch 15,000  of  46,094.    Elapsed: 4:02:40.
#   current average loss = 0.012917813267676381
#   Batch 15,500  of  46,094.    Elapsed: 4:10:50.
#   current average loss = 0.012888781620670406
#   Batch 16,000  of  46,094.    Elapsed: 4:18:59.
#   current average loss = 0.012946900678134
#   Batch 16,500  of  46,094.    Elapsed: 4:27:10.
#   current average loss = 0.012894701353529991
#   Batch 17,000  of  46,094.    Elapsed: 4:35:21.
#   current average loss = 0.01297400844386298
#   Batch 17,500  of  46,094.    Elapsed: 4:43:31.
#   current average loss = 0.013004013270218327
#   Batch 18,000  of  46,094.    Elapsed: 4:51:41.
#   current average loss = 0.012989347554913214
#   Batch 18,500  of  46,094.    Elapsed: 4:59:51.
#   current average loss = 0.012944011736325568
#   Batch 19,000  of  46,094.    Elapsed: 5:08:01.
#   current average loss = 0.01291465542279112
#   Batch 19,500  of  46,094.    Elapsed: 5:16:11.
#   current average loss = 0.012916290395550487
#   Batch 20,000  of  46,094.    Elapsed: 5:24:22.
#   current average loss = 0.012974467671990396
#   Batch 20,500  of  46,094.    Elapsed: 5:32:32.
#   current average loss = 0.012879036895693589
#   Batch 21,000  of  46,094.    Elapsed: 5:40:42.
#   current average loss = 0.012851893435626975
#   Batch 21,500  of  46,094.    Elapsed: 5:48:52.
#   current average loss = 0.012860082739365933
#   Batch 22,500  of  46,094.    Elapsed: 6:05:13.
#   current average loss = 0.012824462385289372
#   Batch 23,000  of  46,094.    Elapsed: 6:13:23.
#   current average loss = 0.012778159610880444
#   Batch 23,500  of  46,094.    Elapsed: 6:21:33.
#   current average loss = 0.012715913587906354
#   Batch 24,000  of  46,094.    Elapsed: 6:29:44.
#   current average loss = 0.012667869420024128
#   Batch 24,500  of  46,094.    Elapsed: 6:37:54.
#   current average loss = 0.012648703660400148
#   Batch 25,000  of  46,094.    Elapsed: 6:46:05.
#   current average loss = 0.012603991279420006
#   Batch 25,500  of  46,094.    Elapsed: 6:54:15.
#   current average loss = 0.012645122692014553
#   Batch 26,000  of  46,094.    Elapsed: 7:02:27.
#   current average loss = 0.012731729139081346
#   Batch 26,500  of  46,094.    Elapsed: 7:10:36.
#   current average loss = 0.012732174746566979
#   Batch 27,000  of  46,094.    Elapsed: 7:18:45.
#   current average loss = 0.012686926726273062
#   Batch 27,500  of  46,094.    Elapsed: 7:26:55.
#   current average loss = 0.012640525932612284
#   Batch 28,000  of  46,094.    Elapsed: 7:35:05.
#   current average loss = 0.012621094191769868
#   Batch 28,500  of  46,094.    Elapsed: 7:43:15.
#   current average loss = 0.012659999775755989
#   Batch 29,000  of  46,094.    Elapsed: 7:51:25.
#   current average loss = 0.012760657999813515
#   Batch 29,500  of  46,094.    Elapsed: 7:59:36.
#   current average loss = 0.012771225776152462
#   Batch 30,000  of  46,094.    Elapsed: 8:07:46.
#   current average loss = 0.012829335567360855
#   Batch 30,500  of  46,094.    Elapsed: 8:15:58.
#   current average loss = 0.012802476792099607
#   Batch 31,000  of  46,094.    Elapsed: 8:24:07.
#   current average loss = 0.01276229858104172
#   Batch 31,500  of  46,094.    Elapsed: 8:32:18.
#   current average loss = 0.012709699723553057
#   Batch 32,000  of  46,094.    Elapsed: 8:40:28.
#   current average loss = 0.01274250891510377
#   Batch 32,500  of  46,094.    Elapsed: 8:48:39.
#   current average loss = 0.012727171032380396
#   Batch 33,000  of  46,094.    Elapsed: 8:56:49.
#   current average loss = 0.012681579869516953
#   Batch 33,500  of  46,094.    Elapsed: 9:04:59.
#   current average loss = 0.012635022848212715
#   Batch 34,000  of  46,094.    Elapsed: 9:13:10.
#   current average loss = 0.012634632779432596
#   Batch 34,500  of  46,094.    Elapsed: 9:21:20.
#   current average loss = 0.012632141153788403
#   Batch 35,000  of  46,094.    Elapsed: 9:29:29.
#   current average loss = 0.01262423324409917
#   Batch 35,500  of  46,094.    Elapsed: 9:37:39.
#   current average loss = 0.012622046674109275
#   Batch 36,000  of  46,094.    Elapsed: 9:45:49.
#   current average loss = 0.012634443177163676
#   Batch 36,500  of  46,094.    Elapsed: 9:54:00.
#   current average loss = 0.012606967484879595
#   Batch 37,000  of  46,094.    Elapsed: 10:02:10.
#   current average loss = 0.012602192417785478
#   Batch 37,500  of  46,094.    Elapsed: 10:10:16.
#   current average loss = 0.012585525876427613
#   Batch 38,000  of  46,094.    Elapsed: 10:18:27.
#   current average loss = 0.012565114260238213
#   Batch 38,500  of  46,094.    Elapsed: 10:26:37.
#   current average loss = 0.012562199995663643
#   Batch 39,000  of  46,094.    Elapsed: 10:34:47.
#   current average loss = 0.012560566103216703
#   Batch 39,500  of  46,094.    Elapsed: 10:42:56.
#   current average loss = 0.012544387467883018
#   Batch 40,500  of  46,094.    Elapsed: 10:59:14.
#   current average loss = 0.01251813245827999
#   Batch 41,000  of  46,094.    Elapsed: 11:07:18.
#   current average loss = 0.012502722800288545
#   Batch 41,500  of  46,094.    Elapsed: 11:15:22.
#   current average loss = 0.01246871733149934
#   Batch 42,000  of  46,094.    Elapsed: 11:23:24.
#   current average loss = 0.012467697578921529
#   Batch 42,500  of  46,094.    Elapsed: 11:31:28.
#   current average loss = 0.012467053364131168
#   Batch 43,000  of  46,094.    Elapsed: 11:39:32.
#   current average loss = 0.012477502988199038
#   Batch 43,500  of  46,094.    Elapsed: 11:47:35.
#   current average loss = 0.012456253260150856
#   Batch 44,000  of  46,094.    Elapsed: 11:55:39.
#   current average loss = 0.012445329997639212
#   Batch 44,500  of  46,094.    Elapsed: 12:03:44.
#   current average loss = 0.012433968684616027
#   Batch 45,000  of  46,094.    Elapsed: 12:11:46.
#   current average loss = 0.012432198816377867
#   Batch 45,500  of  46,094.    Elapsed: 12:19:49.
#   current average loss = 0.012455453420974384
#   Batch 46,000  of  46,094.    Elapsed: 12:27:54.
#   current average loss = 0.012452651187106827
#
#   Average training loss: 0.01245101247230857
#   Training epoch took: 12:29:23
#
# Running Validation...
#   Average validation loss: 0.01126444951773307
#   Accuracy: 0.9953875439281531
#   Validation took: 0:27:20
#
# ======== Epoch 7 / 10 ========
# Training...
#   Batch   500  of  46,094.    Elapsed: 0:08:12.
#   current average loss = 0.011387320019744948
#   Batch 1,000  of  46,094.    Elapsed: 0:16:25.
#   current average loss = 0.011265467407680262
#   Batch 1,500  of  46,094.    Elapsed: 0:24:36.
#   current average loss = 0.010084189116758353
#   Batch 2,000  of  46,094.    Elapsed: 0:32:46.
#   current average loss = 0.009629107475243927
#   Batch 2,500  of  46,094.    Elapsed: 0:40:58.
#   current average loss = 0.009849424286790963
#   Batch 3,000  of  46,094.    Elapsed: 0:49:09.
#   current average loss = 0.009945278105798025
#   Batch 3,500  of  46,094.    Elapsed: 0:57:19.
#   current average loss = 0.009994455837462477
#   Batch 4,000  of  46,094.    Elapsed: 1:05:34.
#   current average loss = 0.009884228536354157
#   Batch 4,500  of  46,094.    Elapsed: 1:13:45.
#   current average loss = 0.009882468177982244
#   Batch 5,000  of  46,094.    Elapsed: 1:21:56.
#   current average loss = 0.009928113724056492
#   Batch 5,500  of  46,094.    Elapsed: 1:30:08.
#   current average loss = 0.009866043186017453
#   Batch 6,000  of  46,094.    Elapsed: 1:38:18.
#   current average loss = 0.010052349077754874
#   Batch 6,500  of  46,094.    Elapsed: 1:46:30.
#   current average loss = 0.010192512841247942
#   Batch 7,000  of  46,094.    Elapsed: 1:54:42.
#   current average loss = 0.010102375301540503
#   Batch 7,500  of  46,094.    Elapsed: 2:02:52.
#   current average loss = 0.01006101467774024
#   Batch 8,000  of  46,094.    Elapsed: 2:11:04.
#   current average loss = 0.01002325204917554
#   Batch 8,500  of  46,094.    Elapsed: 2:19:16.
#   current average loss = 0.009877001991366983
#   Batch 9,000  of  46,094.    Elapsed: 2:27:28.
#   current average loss = 0.009923057610415727
#   Batch 9,500  of  46,094.    Elapsed: 2:35:38.
#   current average loss = 0.009900366603616548
#   Batch 10,000  of  46,094.    Elapsed: 2:43:49.
#   current average loss = 0.009855124045738831
#   Batch 10,500  of  46,094.    Elapsed: 2:51:59.
#   current average loss = 0.009869570194801955
#   Batch 11,000  of  46,094.    Elapsed: 3:00:10.
#   current average loss = 0.009902946328755454
#   Batch 11,500  of  46,094.    Elapsed: 3:08:21.
#   current average loss = 0.009883679588799286
#   Batch 12,000  of  46,094.    Elapsed: 3:16:32.
#   current average loss = 0.00988875793517953
#   Batch 12,500  of  46,094.    Elapsed: 3:24:43.
#   current average loss = 0.009878296810051179
#   Batch 13,000  of  46,094.    Elapsed: 3:32:53.
#   current average loss = 0.00980578006125975
#   Batch 13,500  of  46,094.    Elapsed: 3:41:04.
#   current average loss = 0.009802083011150832
#   Batch 14,000  of  46,094.    Elapsed: 3:49:15.
#   current average loss = 0.00994737792161004
#   Batch 14,500  of  46,094.    Elapsed: 3:57:26.
#   current average loss = 0.00998720870969712
#   Batch 15,000  of  46,094.    Elapsed: 4:05:28.
#   current average loss = 0.009999256304337359
#   Batch 15,500  of  46,094.    Elapsed: 4:13:30.
#   current average loss = 0.009952349744973676
#   Batch 16,000  of  46,094.    Elapsed: 4:21:33.
#   current average loss = 0.009910250649901286
#   Batch 16,500  of  46,094.    Elapsed: 4:29:35.
#   current average loss = 0.009949077980466731
#   Batch 17,000  of  46,094.    Elapsed: 4:37:38.
#   current average loss = 0.010005614071505239
#   Batch 17,500  of  46,094.    Elapsed: 4:45:41.
#   current average loss = 0.010007427127791535
#   Batch 18,000  of  46,094.    Elapsed: 4:53:43.
#   current average loss = 0.010033620181697189
#   Batch 18,500  of  46,094.    Elapsed: 5:01:47.
#   current average loss = 0.010040841938183016
#   Batch 19,000  of  46,094.    Elapsed: 5:09:51.
#   current average loss = 0.010034051830517695
#   Batch 19,500  of  46,094.    Elapsed: 5:17:54.
#   current average loss = 0.010042352657011202
#   Batch 20,000  of  46,094.    Elapsed: 5:25:57.
#   current average loss = 0.010058944079635512
#   Batch 20,500  of  46,094.    Elapsed: 5:34:01.
#   current average loss = 0.009995196307719709
#   Batch 21,000  of  46,094.    Elapsed: 5:42:05.
#   current average loss = 0.01004179068092145
#   Batch 21,500  of  46,094.    Elapsed: 5:50:08.
#   current average loss = 0.010006730743754815
#   Batch 22,000  of  46,094.    Elapsed: 5:58:11.
#   current average loss = 0.010004388970449161
#   Batch 22,500  of  46,094.    Elapsed: 6:06:15.
#   current average loss = 0.00998219652345898
#   Batch 23,000  of  46,094.    Elapsed: 6:14:18.
#   current average loss = 0.009991655985957748
#   Batch 23,500  of  46,094.    Elapsed: 6:22:21.
#   current average loss = 0.010000031937306553
#   Batch 24,000  of  46,094.    Elapsed: 6:30:24.
#   current average loss = 0.009956037282895675
#   Batch 24,500  of  46,094.    Elapsed: 6:38:27.
#   current average loss = 0.009973593374276696
#   Batch 25,000  of  46,094.    Elapsed: 6:46:31.
#   current average loss = 0.0100251623261434
#   Batch 25,500  of  46,094.    Elapsed: 6:54:37.
#   current average loss = 0.010048599723883622
#   Batch 26,000  of  46,094.    Elapsed: 7:02:39.
#   current average loss = 0.010066063236704184
#   Batch 26,500  of  46,094.    Elapsed: 7:10:42.
#   current average loss = 0.010053441841265047
#   Batch 27,000  of  46,094.    Elapsed: 7:18:45.
#   current average loss = 0.010048184325160575
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-caf39c5d6edf> in <module>
#      75
#      76         # Backward 수행으로 그래디언트 계산
# ---> 77         loss.backward()
#      78
#      79         # 그래디언트 클리핑
#
# /usr/local/lib/python3.6/dist-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     219                 retain_graph=retain_graph,
#     220                 create_graph=create_graph)
# --> 221         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     222
#     223     def register_hook(self, hook):
#
# /usr/local/lib/python3.6/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#     130     Variable._execution_engine.run_backward(
#     131         tensors, grad_tensors_, retain_graph, create_graph,
# --> 132         allow_unreachable=True)  # allow_unreachable flag
#     133
#     134
#
# KeyboardInterrupt:

# %% [markdown]
# # Prediction Code

# %%
test_contents = test['요약문_내용'].values 
test_feature1 = test['사업명'].values 
test_feature2 = test['사업_부처명'].values 
test_feature3 = test['내역사업명'].values
test_feature4 = test['과제명'].values
test_feature5 = test['요약문_한글키워드'].values 
test_feature6 = test['요약문_영문키워드'].values

# %%
# Load KoBERT
bert_checkpoint = torch.load('KoBERT_DIFFERENT_CONFIG_6') 
test_bert = BertForSequenceClassification.from_pretrained("skt/kobert-base-v1", num_labels=46) 
test_bert.load_state_dict(bert_checkpoint) 
test_bert.cuda() 
print()
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at skt/kobert-base-v1 and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
import torch.nn.functional as nnf

bert_probsum = [] 
bert_chunkparts = [] 

# change to eval mode 
test_bert.eval() 


for i in tqdm(range(test_contents.shape[0]), position = 0, leave=True): 
    f1 = clean_text(str(test_feature1[i])) 
    f2 = clean_text(str(test_feature2[i])) 
    f3 = clean_text(str(test_feature3[i])) 
    f4 = clean_text(str(test_feature4[i])) 
    f5 = str(test_feature5[i]) 
    splitted = split_text(clean_text(str(test_contents[i])))
    probabilities_bert = [] 
    for text in splitted: 
        test_text = f1 + " " + f2 + " " + f3 + " " + f4 + " " + f5 + " " + text 
        # tokenize test text 
        input_id, attention_mask, token_type_id = bert_tokenizer(test_text, MAX_LEN=MAX_LEN) 
        input_id = torch.tensor(input_id) 
        attention_mask = torch.tensor(attention_mask) 
        token_type_id = torch.tensor(token_type_id) 
        # reshape into (batch, MAX_LEN) 
        input_id = torch.reshape(input_id, (-1, MAX_LEN)) 
        attention_mask = torch.reshape(attention_mask, (-1, MAX_LEN))  
        token_type_id = torch.reshape(token_type_id, (-1, MAX_LEN)) 
        # move tensor to cuda 
        input_id = input_id.to(device) 
        attention_mask = attention_mask.to(device) 
        token_type_id = token_type_id.to(device) 
        
        with torch.no_grad(): 
            outputs = test_bert(input_id, 
                                token_type_ids=token_type_id, 
                                attention_mask = attention_mask) 
            
        logits = outputs[0] 
        
        # obtain softmax probabilities 
        prob = nnf.softmax(logits, dim=1).flatten() 
        probabilities_bert.append(prob) 
        
    # soft voting 
    prob_sum = np.zeros(46) 
    for i in range(len(probabilities_bert)): 
        for j in range(46):  
            prob_sum[j] += probabilities_bert[i][j] 
    
    bert_probsum.append(prob_sum)
    bert_chunkparts.append(len(probabilities_bert)) 
    

bert_probsum = np.asarray(bert_probsum) 
bert_chunkparts = np.asarray(bert_chunkparts)
# Out:
#   7%|▋         | 3141/43576 [10:42<2:07:11,  5.30it/s]
# Long Text!! Using the first 512 tokens
# Long Text!! Using the first 512 tokens
# Long Text!! Using the first 512 tokens
# Long Text!! Using the first 512 tokens
# Long Text!! Using the first 512 tokens
#  20%|█▉        | 8594/43576 [30:11<2:17:41,  4.23it/s]
# Long Text!! Using the first 512 tokens
#  62%|██████▏   | 27182/43576 [1:34:28<44:07,  6.19it/s]
# Long Text!! Using the first 512 tokens
# Long Text!! Using the first 512 tokens
# Long Text!! Using the first 512 tokens
# 100%|██████████| 43576/43576 [2:31:28<00:00,  4.79it/s]
# saving predicted probability values
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-352894cb4922> in <module>
#      57
#      58 print("saving predicted probability values")
# ---> 59 np.save('bert_probsum_2.npy', bert_probum)
#      60 np.save('bert_chunkparts_2.npy', bert_chunkparts)
#      61
#
# NameError: name 'bert_probum' is not defined

# %%
print("saving predicted probability values") 
np.save('bert_probsum_2.npy', bert_probsum) 
np.save('bert_chunkparts_2.npy', bert_chunkparts)
# Out:
# saving predicted probability values

# %%
bert_probsum
# Out:
# array([[1.39996986e+01, 2.92763457e-06, 2.31417268e-08, ...,
#         8.18598153e-07, 3.20058433e-08, 1.07785363e-05],
#        [1.59998016e+01, 1.82669692e-06, 6.93749271e-08, ...,
#         1.44548790e-06, 3.81685567e-07, 9.28362078e-06],
#        [5.99995518e+00, 3.86897739e-07, 9.11096620e-09, ...,
#         3.82379937e-07, 3.51047014e-08, 3.50270693e-06],
#        ...,
#        [1.45434072e-07, 5.20826507e-06, 7.99969864e+00, ...,
#         1.17021982e-05, 4.48026949e-05, 1.67731051e-09],
#        [8.99993134e+00, 8.92271430e-07, 2.80280119e-08, ...,
#         7.02174191e-07, 8.29793265e-08, 3.31755064e-06],
#        [3.99960995e+00, 4.35817157e-07, 9.73338032e-09, ...,
#         7.03599198e-07, 1.64671476e-08, 2.16815374e-06]])
